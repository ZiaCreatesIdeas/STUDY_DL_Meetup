# %% [markdown]
# The origins of ChatGPT: <br>
# ### Training language models to follow instructions with human feedback <br>
# https://arxiv.org/abs/2203.02155

# %% [markdown]
# ![Screen%20Shot%202023-02-22%20at%209.32.45%20AM.png](attachment:Screen%20Shot%202023-02-22%20at%209.32.45%20AM.png)

# %% [markdown]
# #### Uses a mix of supervised learning and RL!

# %% [markdown]
# ![Screen%20Shot%202023-02-22%20at%209.26.41%20AM.png](attachment:Screen%20Shot%202023-02-22%20at%209.26.41%20AM.png)

# %% [markdown]
# #### *From the graph captions, whose is it that 'prefers'?*

# %% [markdown]
# Strong focus on 'helpful', but that requires some defining what is and is not helpful.<br>
# ![Screen%20Shot%202023-02-22%20at%209.34.58%20AM.png](attachment:Screen%20Shot%202023-02-22%20at%209.34.58%20AM.png)

# %% [markdown]
# Fascinating what they were able to accomplish with just 40 contractors. Not even employees. I'd love to know more about who designed the screening test? Was that another 40 contractors to dilute bias in the screening or just one person? <br>
# ![Screen%20Shot%202023-02-22%20at%209.37.23%20AM.png](attachment:Screen%20Shot%202023-02-22%20at%209.37.23%20AM.png)

# %% [markdown]
# ![Screen%20Shot%202023-02-22%20at%209.40.03%20AM.png](attachment:Screen%20Shot%202023-02-22%20at%209.40.03%20AM.png)

# %% [markdown]
# ![Screen%20Shot%202023-02-22%20at%209.42.58%20AM.png](attachment:Screen%20Shot%202023-02-22%20at%209.42.58%20AM.png)

# %% [markdown]
# ### Definitions: RLHF - Reinforcement Learning from Human Feedback <br>
# https://huggingface.co/blog/rlhf

# %% [markdown]
# **Interesting idea to have a prompt to be respectful. Maybe that should be the default or is it better to get the raw data?**

# %% [markdown]
# ![Screen%20Shot%202023-02-22%20at%209.47.52%20AM.png](attachment:Screen%20Shot%202023-02-22%20at%209.47.52%20AM.png)

# %% [markdown]
# Noted: Improvements over toxicity, but not bias. As measured by RealToxicityPrompts, not humans.

# %% [markdown]
# Not clear on the meaning of this method.
# ![Screen%20Shot%202023-02-22%20at%209.51.11%20AM.png](attachment:Screen%20Shot%202023-02-22%20at%209.51.11%20AM.png)

# %% [markdown]
# #### Noted. Known failings: "InstructGPT still makes simple mistakes. For example, InstructGPT can still fail to follow instructions, make up facts, give long hedging answers to simple questions, or fail to detect instructions with false premises."

# %% [markdown]
# #### Definition. Causal Mediation Analaysis:
# Causal mediation analysis (CMA) is a method to dissect total effect of a treatment into direct and indirect effect. The indirect effect is transmitted via mediator to the outcome. The mediation package is designed to perform CMA under the assumption of sequential ignorability.
